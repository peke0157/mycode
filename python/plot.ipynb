# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
from pathlib import Path

file_name = "dataset/5-263902-A-36"
y, sr = librosa.load(file_name)

L = len(y)
t = np.arange(0,L) / sr

plt.plot(t,y)
plt.title('Audio waveform')
plt.xlabel('time(s)')
plt.ylabel('Amplitude')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
from pathlib import Path

base_dir = Path('test/classical')
for audio_dir in base_dir.glob('*.wav'):
    y, sr = librosa.load(audio_dir)

    L = len(y)
    t = np.arange(0,L) / sr

    plt.plot(t,y)
    plt.title('Audio waveform')
    plt.xlabel('time(s)')
    plt.ylabel('Amplitude')

    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
from pathlib import Path
import math


base_dir = Path('test')
for audio_dir in base_dir.glob('*.wav'):
    y, sr = librosa.load(audio_dir)

    L = len(y)
    t = np.arange(0,L) / sr

    Y = np.fft(y)
    
    plt.plot(t,y)
    plt.title('Audio waveform')
    plt.xlabel('time(s)')
    plt.ylabel('Amplitude')

    plt.show()
